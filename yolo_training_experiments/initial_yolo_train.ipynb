# %%
# Load the nano model and train on 3 epochs

model = YOLO("yolov8n.yaml")  # trying the nano version first

# Use the model
results = model.train(data="vision.yaml",
            epochs=3,
            resume = True,
            batch = -1,
            imgsz = 96,
            project = 'facial_expressions_dataset',
            fraction = 0.01)  # train the model on a sample
# Out:
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
################################################################################################################

# %%
#using the previous version of yolo due to compatibility issues
# %pip install ultralytics==8.1.23
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.3/719.3 kB 12.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# device(type='cpu')

# %%
# Load the small pretrained model on 5 epochs
model = YOLO("yolov8s.pt")

# Use the model
results = model.train(data="/content/drive/MyDrive/facial_expressions_dataset/new_yolo_images/vision.yaml",
            epochs=5,
            #resume = True,
            batch = -1,
            imgsz = 96,
            project = 'facial_expressions_dataset',
            device='cpu'
            )
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 257MB/s]
# New https://pypi.org/project/ultralytics/8.1.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# saving the results
# !scp -r /content/facial_expressions_dataset '/content/drive/MyDrive/facial_expressions_dataset/results_full_dataset_run2_complete'

# %%
################################################################################################################

# %%
# training the nano pretrained model on 3 epochs

model = YOLO("yolov8n.pt")

# Use the model
results = model.train(data="/content/drive/MyDrive/facial_expressions_dataset/new_yolo_images/vision.yaml",
            epochs=3,
            #resume = True,
            batch = -1,
            imgsz = 96,
            project = 'facial_expressions_dataset'
            )
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...
